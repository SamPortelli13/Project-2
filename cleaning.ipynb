# %%
# Depenencies
import pandas as pd
from sqlalchemy import create_engine, inspect, func
import csv, os
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from flask import jsonify

# %%
# Importing csv files
ufo_path = "static/Resources/ufo_reports_raw.CSV"
ufo_data = pd.read_csv(ufo_path)

# %% [markdown]
# # Transformation Phase (Cleaning)

# %% [markdown]
# ### USA UFO Sightings

# %%
ufo_data.head()
# Out:
#                                              summary        city state  \
# 0                                     freaked me out    San Jose    CA
# 1  One object observed at closer ground distance,...    Somerset    KY
# 2  UFO contact we made during Desert Shield in th...         NaN   NaN
# 3  Over a course of 5 years, I have seen UFOs, ob...  Germantown    MD
# 4  Driving north on US 87 just outside Brady, Tex...       Brady    TX
#
#              date_time      shape          duration  \
# 0  2021-05-06T21:00:00     sphere         2 minutes
# 1                  NaN    unknown        2400 hours
# 2                  NaN        NaN               NaN
# 3  2005-07-06T12:00:00  formation             Years
# 4  2020-01-29T19:45:00      light  Lights disappear
#
#                                                stats  \
# 0  Occurred : 5/6/2021 21:00  (Entered as : 05/06...
# 1  Occurred :   Reported: 12/21/2019 8:49:14 PM 2...
# 2  Occurred :   Reported: 5/16/2021 4:55:36 PM 16...
# 3  Occurred : 7/6/1905 12:00  (Entered as : 2014 ...
# 4  Occurred : 1/29/2020 19:45  (Entered as : 01/2...
#
#                                          report_link  \
# 0  http://www.nuforc.org/webreports/163/S163041.html
# 1  http://www.nuforc.org/webreports/151/S151813.html
# 2  http://www.nuforc.org/webreports/163/S163175.html
# 3  http://www.nuforc.org/webreports/162/S162867.html
# 4  http://www.nuforc.org/webreports/152/S152953.html
#
#                                                 text               posted  \
# 0  freaked me out I looked up into the night sky ...  2021-05-20T00:00:00
# 1  One object observed at closer ground distance,...                  NaN
# 2  UFO contact we made during Desert Shield in th...                  NaN
# 3  Over a course of 5 years, I have seen UFOs, ob...  2021-05-20T00:00:00
# 4  Driving north on US 87 just outside Brady, Tex...  2020-01-31T00:00:00
#
#    city_latitude  city_longitude
# 0      37.338842     -121.889706
# 1      37.090361      -84.498169
# 2            NaN             NaN
# 3      39.154986      -77.272538
# 4      31.145100      -99.347800

# %%
# Split date_time column
ufo_data[["date","time"]] = ufo_data['date_time'].str.split("T",expand=True)

# Convert date and time columns data type
ufo_data['date'] = pd.to_datetime(ufo_data['date'])
ufo_data['time'] = pd.to_datetime(ufo_data['time'])

# %%
ufo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98353 entries, 0 to 98352
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         98305 non-null  object
#  1   city            98052 non-null  object
#  2   state           92707 non-null  object
#  3   date_time       97027 non-null  object
#  4   shape           94682 non-null  object
#  5   duration        93952 non-null  object
#  6   stats           98316 non-null  object
#  7   report_link     98353 non-null  object
#  8   text            98280 non-null  object
#  9   posted          97027 non-null  object
#  10  city_latitude   80483 non-null  float64
#  11  city_longitude  80483 non-null  float64
#  12  date            97027 non-null  datetime64[ns]
#  13  time            97027 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(10)
# memory usage: 10.5+ MB

# %%
#ufo_data.columns

to_drop = ['posted',
            'stats',
            'report_link',
            'date_time',
            'text'
            ]

ufo_data.drop(to_drop, axis=1, inplace=True)

ufo_data.head()
# Out:
#                                              summary        city state  \
# 0                                     freaked me out    San Jose    CA
# 1  One object observed at closer ground distance,...    Somerset    KY
# 2  UFO contact we made during Desert Shield in th...         NaN   NaN
# 3  Over a course of 5 years, I have seen UFOs, ob...  Germantown    MD
# 4  Driving north on US 87 just outside Brady, Tex...       Brady    TX
#
#        shape          duration  city_latitude  city_longitude       date  \
# 0     sphere         2 minutes      37.338842     -121.889706 2021-05-06
# 1    unknown        2400 hours      37.090361      -84.498169        NaT
# 2        NaN               NaN            NaN             NaN        NaT
# 3  formation             Years      39.154986      -77.272538 2005-07-06
# 4      light  Lights disappear      31.145100      -99.347800 2020-01-29
#
#                  time
# 0 2021-12-13 21:00:00
# 1                 NaT
# 2                 NaT
# 3 2021-12-13 12:00:00
# 4 2021-12-13 19:45:00

# %%
# Drop UFO Sightings with no city and date
ufo_df = ufo_data.dropna(subset=['city', 'date', 'time'])

ufo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96774 entries, 0 to 98352
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         96730 non-null  object
#  1   city            96774 non-null  object
#  2   state           91394 non-null  object
#  3   shape           93309 non-null  object
#  4   duration        92607 non-null  object
#  5   city_latitude   79569 non-null  float64
#  6   city_longitude  79569 non-null  float64
#  7   date            96774 non-null  datetime64[ns]
#  8   time            96774 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 7.4+ MB

# %%
# Replacing NA values
values = {  'summary': 'observed', 
            'shape':'other',
            'duration':'unknown',
            'text':'observed'
            }
ufo_df2 = ufo_df.fillna(value=values)
ufo_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96774 entries, 0 to 98352
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         96774 non-null  object
#  1   city            96774 non-null  object
#  2   state           91394 non-null  object
#  3   shape           96774 non-null  object
#  4   duration        96774 non-null  object
#  5   city_latitude   79569 non-null  float64
#  6   city_longitude  79569 non-null  float64
#  7   date            96774 non-null  datetime64[ns]
#  8   time            96774 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 7.4+ MB

# %%
# Change time column to day or night
def determine_time(time):
    h = time.hour
    return (
        "morning"
        if 5 <= h <= 11
        else "afternoon"
        if 12 <= h <= 17
        else "evening"
        if 18 <= h <= 22
        else "night"
    )

ufo_df2['time'] = ufo_df2.apply(lambda row: determine_time(row[8]), axis=1)

ufo_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96774 entries, 0 to 98352
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         96774 non-null  object
#  1   city            96774 non-null  object
#  2   state           91394 non-null  object
#  3   shape           96774 non-null  object
#  4   duration        96774 non-null  object
#  5   city_latitude   79569 non-null  float64
#  6   city_longitude  79569 non-null  float64
#  7   date            96774 non-null  datetime64[ns]
#  8   time            96774 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 7.4+ MB

# %%
ufo_df2.head()
# Out:
#                                              summary        city state  \
# 0                                     freaked me out    San Jose    CA
# 3  Over a course of 5 years, I have seen UFOs, ob...  Germantown    MD
# 4  Driving north on US 87 just outside Brady, Tex...       Brady    TX
# 5                              meteor or space junk?   San Diego    CA
# 6  Shaped like a triangle, transparent like a lig...   Las Vegas    NV
#
#        shape          duration  city_latitude  city_longitude       date  \
# 0     sphere         2 minutes      37.338842     -121.889706 2021-05-06
# 3  formation             Years      39.154986      -77.272538 2005-07-06
# 4      light  Lights disappear      31.145100      -99.347800 2020-01-29
# 5   fireball         2 seconds      32.787229     -117.140268 2020-01-29
# 6   triangle                30      36.141246     -115.186592 2020-01-28
#
#         time
# 0    evening
# 3  afternoon
# 4    evening
# 5    evening
# 6  afternoon

# %%
# Re-cast date column into object
ufo_df2['date'] = ufo_df2['date'].dt.strftime("%Y/%m/%d")
ufo_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96774 entries, 0 to 98352
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         96774 non-null  object
#  1   city            96774 non-null  object
#  2   state           91394 non-null  object
#  3   shape           96774 non-null  object
#  4   duration        96774 non-null  object
#  5   city_latitude   79569 non-null  float64
#  6   city_longitude  79569 non-null  float64
#  7   date            96774 non-null  object
#  8   time            96774 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 7.4+ MB

# %%
# Filter data to the past 40 years
# filtered_df = ufo_df2[ufo_df2['date'].dt.year > 1980]
# filtered_df.info()

# %%
# Drop UFO sightings with no coordinates 
ufo_df3 = ufo_df2.dropna(subset=['city_latitude', 'city_longitude'])

# %%
ufo_df3.reset_index(drop=True)
ufo_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79569 entries, 0 to 98352
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         79569 non-null  object
#  1   city            79569 non-null  object
#  2   state           79569 non-null  object
#  3   shape           79569 non-null  object
#  4   duration        79569 non-null  object
#  5   city_latitude   79569 non-null  float64
#  6   city_longitude  79569 non-null  float64
#  7   date            79569 non-null  object
#  8   time            79569 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 6.1+ MB

# %%
# Assign Country Code to Index
usa_id = pd.Series([840 for x in range(len(ufo_df3))])
ufo_df3['country_id'] = usa_id
ufo_df3 = ufo_df3.fillna(value=840)

usa_ufo_df = ufo_df3.set_index('country_id')
usa_ufo_df = usa_ufo_df.rename(columns={'city' : "city_name"})

usa_ufo_df
# Out:
# <ipython-input-16-9c40a9144205>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ufo_df3['country_id'] = usa_id
#                                                       summary       city_name  \
# country_id
# 840.0                                          freaked me out        San Jose
# 840.0       Over a course of 5 years, I have seen UFOs, ob...      Germantown
# 840.0       Driving north on US 87 just outside Brady, Tex...           Brady
# 840.0                                   meteor or space junk?       San Diego
# 840.0       Shaped like a triangle, transparent like a lig...       Las Vegas
# ...                                                       ...             ...
# 840.0                                White bright quick light  St. Petersburg
# 840.0       It’s really hard to explain... other than at f...      Moses lake
# 840.0       Object in sky above me walking my dog. Came do...     Yorba linda
# 840.0       Saw a fuzzy green orb moving at high speed in ...            Apex
# 840.0       I was traveling in my car and looked over and ...         Phoenix
#
#            state      shape          duration  city_latitude  city_longitude  \
# country_id
# 840.0         CA     sphere         2 minutes      37.338842     -121.889706
# 840.0         MD  formation             Years      39.154986      -77.272538
# 840.0         TX      light  Lights disappear      31.145100      -99.347800
# 840.0         CA   fireball         2 seconds      32.787229     -117.140268
# 840.0         NV   triangle                30      36.141246     -115.186592
# ...          ...        ...               ...            ...             ...
# 840.0         FL      flash        ~2 seconds      27.794515      -82.675160
# 840.0         WA    unknown                30      47.190100     -119.307400
# 840.0         CA      light           unknown      33.891402     -117.777835
# 840.0         NC     circle       1-2 seconds      35.717334      -78.880864
# 840.0         AZ      light     30-45 seconds      33.535381     -112.049460
#
#                   date       time
# country_id
# 840.0       2021/05/06    evening
# 840.0       2005/07/06  afternoon
# 840.0       2020/01/29    evening
# 840.0       2020/01/29    evening
# 840.0       2020/01/28  afternoon
# ...                ...        ...
# 840.0       2021/03/27      night
# 840.0       2021/03/27      night
# 840.0       2021/03/27      night
# 840.0       2021/03/28    evening
# 840.0       2021/03/28    evening
#
# [79569 rows x 9 columns]

# %%
usa_ufo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 79569 entries, 840.0 to 840.0
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         79569 non-null  object
#  1   city_name       79569 non-null  object
#  2   state           79569 non-null  object
#  3   shape           79569 non-null  object
#  4   duration        79569 non-null  object
#  5   city_latitude   79569 non-null  float64
#  6   city_longitude  79569 non-null  float64
#  7   date            79569 non-null  object
#  8   time            79569 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 6.1+ MB

# %% [markdown]
# ### Other Country UFO Sightings

# %%
other_ufo_df = ufo_df2[ufo_df2['state'].isnull()]
other_ufo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5380 entries, 12 to 98344
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         5380 non-null   object
#  1   city            5380 non-null   object
#  2   state           0 non-null      object
#  3   shape           5380 non-null   object
#  4   duration        5380 non-null   object
#  5   city_latitude   0 non-null      float64
#  6   city_longitude  0 non-null      float64
#  7   date            5380 non-null   object
#  8   time            5380 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 420.3+ KB

# %%
other_ufo_df.head()
# Out:
#                                                summary  \
# 12   A series of soft white lights were traveling i...
# 84                       Big UFO hovering over a house
# 88               30+ orange balls playing in Australia
# 96   Simple triangle 40/50 yards across. Blue soft ...
# 103  Incredible bright light flooding the room, acc...
#
#                                                  city state     shape  \
# 12                                    Chennai (India)   NaN     light
# 84                                Comalcalco (Mexico)   NaN     other
# 88                                 Hobart (Australia)   NaN  fireball
# 96                                 Hahn A B (Germany)   NaN  triangle
# 103  Chipping (small village, Lancashire)(UK/England)   NaN     other
#
#           duration  city_latitude  city_longitude        date       time
# 12   10-15 minutes            NaN             NaN  2020/01/10    morning
# 84            4:00            NaN             NaN  1980/06/01  afternoon
# 88       5 minutes            NaN             NaN  1982/03/16    evening
# 96       7 minutes            NaN             NaN  1988/06/01      night
# 103   3-30 minutes            NaN             NaN  1990/06/01      night

# %%
# Split city column to obtain country
other_ufo_df[['new1', 'new2', 'new3']] = other_ufo_df['city'].str.split( '(' , expand=True, n=2)

# Drop Columns with no city and country combination
other_ufo_df = other_ufo_df.dropna(subset=['new2'])
other_ufo_df = other_ufo_df.drop(other_ufo_df[other_ufo_df['new3'].notnull()].index)
other_ufo_df.drop('new3', axis=1, inplace=True)

other_ufo_df.head()
# Out:
# C:\Users\sampo\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                                summary  \
# 12   A series of soft white lights were traveling i...
# 84                       Big UFO hovering over a house
# 88               30+ orange balls playing in Australia
# 96   Simple triangle 40/50 yards across. Blue soft ...
# 123                                       Cube of Fire
#
#                             city state     shape       duration  \
# 12               Chennai (India)   NaN     light  10-15 minutes
# 84           Comalcalco (Mexico)   NaN     other           4:00
# 88            Hobart (Australia)   NaN  fireball      5 minutes
# 96            Hahn A B (Germany)   NaN  triangle      7 minutes
# 123  Stoke on Trent (UK/England)   NaN  fireball      4 minutes
#
#      city_latitude  city_longitude        date       time             new1  \
# 12             NaN             NaN  2020/01/10    morning         Chennai
# 84             NaN             NaN  1980/06/01  afternoon      Comalcalco
# 88             NaN             NaN  1982/03/16    evening          Hobart
# 96             NaN             NaN  1988/06/01      night        Hahn A B
# 123            NaN             NaN  1999/04/04    evening  Stoke on Trent
#
#             new2
# 12        India)
# 84       Mexico)
# 88    Australia)
# 96      Germany)
# 123  UK/England)

# %%
# Rename columns and drop unnecessary column
other_ufo_df.drop('city', axis=1, inplace=True)
other_ufo_df = other_ufo_df.rename(columns={"new1": "city_name", "new2": "country_name"})
other_ufo_df['country_name'] = other_ufo_df['country_name'].str.replace( ')','', regex=True)
#other_ufo_df['city_name'] = other_ufo_df['city_name'].str.replace( ' ','', regex=True)

other_ufo_df.head()
# Out:
#                                                summary state     shape  \
# 12   A series of soft white lights were traveling i...   NaN     light
# 84                       Big UFO hovering over a house   NaN     other
# 88               30+ orange balls playing in Australia   NaN  fireball
# 96   Simple triangle 40/50 yards across. Blue soft ...   NaN  triangle
# 123                                       Cube of Fire   NaN  fireball
#
#           duration  city_latitude  city_longitude        date       time  \
# 12   10-15 minutes            NaN             NaN  2020/01/10    morning
# 84            4:00            NaN             NaN  1980/06/01  afternoon
# 88       5 minutes            NaN             NaN  1982/03/16    evening
# 96       7 minutes            NaN             NaN  1988/06/01      night
# 123      4 minutes            NaN             NaN  1999/04/04    evening
#
#            city_name country_name
# 12          Chennai         India
# 84       Comalcalco        Mexico
# 88           Hobart     Australia
# 96         Hahn A B       Germany
# 123  Stoke on Trent    UK/England

# %%
# Replacing NA values
values = {  'state': 'unknown'
            }
other_ufo_df = other_ufo_df.fillna(value=values)
other_ufo_df.head()
# Out:
#                                                summary    state     shape  \
# 12   A series of soft white lights were traveling i...  unknown     light
# 84                       Big UFO hovering over a house  unknown     other
# 88               30+ orange balls playing in Australia  unknown  fireball
# 96   Simple triangle 40/50 yards across. Blue soft ...  unknown  triangle
# 123                                       Cube of Fire  unknown  fireball
#
#           duration  city_latitude  city_longitude        date       time  \
# 12   10-15 minutes            NaN             NaN  2020/01/10    morning
# 84            4:00            NaN             NaN  1980/06/01  afternoon
# 88       5 minutes            NaN             NaN  1982/03/16    evening
# 96       7 minutes            NaN             NaN  1988/06/01      night
# 123      4 minutes            NaN             NaN  1999/04/04    evening
#
#            city_name country_name
# 12          Chennai         India
# 84       Comalcalco        Mexico
# 88           Hobart     Australia
# 96         Hahn A B       Germany
# 123  Stoke on Trent    UK/England

# %%
other_ufo_df.drop('city_latitude', axis=1, inplace=True)
other_ufo_df.drop('city_longitude', axis=1, inplace=True)

# %% [markdown]
# ### Combining with other city and country data

# %%
# Importing csv files
country_path = "static/Resources/country_abb.CSV"
country_data = pd.read_csv(country_path, error_bad_lines=False)
# Out:
# b'Skipping line 67: expected 16 fields, saw 17\nSkipping line 126: expected 16 fields, saw 17\nSkipping line 127: expected 16 fields, saw 17\n'

# %%
# Dropping unwanted columns
cleaned_country_df = pd.DataFrame(country_data, columns = {"Country or Area", "M49 Code", "ISO-alpha2 Code"})
cleaned_country_df
# Out:
#     ISO-alpha2 Code            Country or Area  M49 Code
# 0                DZ                    Algeria        12
# 1                EG                      Egypt       818
# 2                LY                      Libya       434
# 3                MA                    Morocco       504
# 4                SD                      Sudan       729
# ..              ...                        ...       ...
# 241              WS                      Samoa       882
# 242              TK                    Tokelau       772
# 243              TO                      Tonga       776
# 244              TV                     Tuvalu       798
# 245              WF  Wallis and Futuna Islands       876
#
# [246 rows x 3 columns]

# %%
cleaned_country_df = cleaned_country_df.rename(columns = {"Country or Area": "country_name",
                                                          "M49 Code":"country_id",
                                                          "ISO-alpha2 Code": "country_abb"})
cleaned_country_df
# Out:
#     country_abb               country_name  country_id
# 0            DZ                    Algeria          12
# 1            EG                      Egypt         818
# 2            LY                      Libya         434
# 3            MA                    Morocco         504
# 4            SD                      Sudan         729
# ..          ...                        ...         ...
# 241          WS                      Samoa         882
# 242          TK                    Tokelau         772
# 243          TO                      Tonga         776
# 244          TV                     Tuvalu         798
# 245          WF  Wallis and Futuna Islands         876
#
# [246 rows x 3 columns]

# %%
# Importing csv files
cities_path = "static/Resources/world_cities.CSV"
cities_df = pd.read_csv(cities_path)

# %%
cleaned_cities_df = cities_df.rename(columns = {"Country": "country_abb",
                                                          "City":"city_name",
                                                          "Latitude": "city_latitude",
                                                          "Longitude": "city_longitude"})


cleaned_cities_df['country_abb'] = cleaned_cities_df['country_abb'].str.upper()
cleaned_cities_df['city_name'] = cleaned_cities_df['city_name'].str.title()

cleaned_cities_df
# Out:
#       country_abb         city_name  city_latitude  city_longitude
# 0              AD  Andorra La Vella      42.500000        1.516667
# 1              AD           Canillo      42.566667        1.600000
# 2              AD            Encamp      42.533333        1.583333
# 3              AD        La Massana      42.550000        1.516667
# 4              AD      Les Escaldes      42.500000        1.533333
# ...           ...               ...            ...             ...
# 46827          ZW         Redcliffe     -19.033333       29.783333
# 46828          ZW            Rusape     -18.533333       32.116667
# 46829          ZW          Shurugwi     -19.666667       30.000000
# 46830          ZW    Victoria Falls     -17.933333       25.833333
# 46831          ZW        Zvishavane     -20.333333       30.033333
#
# [46832 rows x 4 columns]

# %%
other_ufo_df["country_name"].replace({"Usa" : "United States of America", 
                                                         "South Korea" : "Republic of Korea", 
                                                         "Macedonia" :"North Macedonia", 
                                                         "Russia" : "Russian Federation",
                                                        "Venezuela": "Venezuela (Bolivarian Republic of)",
                                                        "Iran": "Iran (Islamic Republic of)",
                                                        "Taiwan": "China",
                                                        "Usa Territory": "United States of America",
                                                        "Myanmar (Burma)": "Myanmar",
                                                        "Kermadec Islands (New Zealand)": "New Zealand",
                                                        "Bosnia-Herzegovina": "Bosnia and Herzegovina",
                                                        "South Georgia And The South Sandwich Islands": "South Georgia and the South Sandwich Islands",
                                                        "Tanzania": "United Republic of Tanzania",
                                                        "Uk" : "United Kingdom of Great Britain and Northern Ireland",
                                                        "Uk Territory" : "United Kingdom of Great Britain and Northern Ireland",
                                                        "UK/England" : "United Kingdom of Great Britain and Northern Ireland",
                                                        "UK/Scotland" : "United Kingdom of Great Britain and Northern Ireland",
                                                        "UK/Wales" : "United Kingdom of Great Britain and Northern Ireland",
                                                        "West Germany" : "Germany",
                                                        "South Australia" : "Australia",
                                                        "Republic of Ireland" : "Ireland",
                                                        "Brunei" : "Brunei Darussalam",
                                                        "Burma" : "Myanmar"}, inplace=True)


other_ufo_df.head()
# Out:
#                                                summary    state     shape  \
# 12   A series of soft white lights were traveling i...  unknown     light
# 84                       Big UFO hovering over a house  unknown     other
# 88               30+ orange balls playing in Australia  unknown  fireball
# 96   Simple triangle 40/50 yards across. Blue soft ...  unknown  triangle
# 123                                       Cube of Fire  unknown  fireball
#
#           duration        date       time        city_name  \
# 12   10-15 minutes  2020/01/10    morning         Chennai
# 84            4:00  1980/06/01  afternoon      Comalcalco
# 88       5 minutes  1982/03/16    evening          Hobart
# 96       7 minutes  1988/06/01      night        Hahn A B
# 123      4 minutes  1999/04/04    evening  Stoke on Trent
#
#                                           country_name
# 12                                               India
# 84                                              Mexico
# 88                                           Australia
# 96                                             Germany
# 123  United Kingdom of Great Britain and Northern I...

# %%
# Merge main_other_df with country_df for the ID and abb
city_data = cleaned_cities_df.merge(cleaned_country_df, on="country_abb", how="inner")
city_data
# Out:
#       country_abb         city_name  city_latitude  city_longitude  \
# 0              AD  Andorra La Vella      42.500000        1.516667
# 1              AD           Canillo      42.566667        1.600000
# 2              AD            Encamp      42.533333        1.583333
# 3              AD        La Massana      42.550000        1.516667
# 4              AD      Les Escaldes      42.500000        1.533333
# ...           ...               ...            ...             ...
# 46695          ZW         Redcliffe     -19.033333       29.783333
# 46696          ZW            Rusape     -18.533333       32.116667
# 46697          ZW          Shurugwi     -19.666667       30.000000
# 46698          ZW    Victoria Falls     -17.933333       25.833333
# 46699          ZW        Zvishavane     -20.333333       30.033333
#
#       country_name  country_id
# 0          Andorra          20
# 1          Andorra          20
# 2          Andorra          20
# 3          Andorra          20
# 4          Andorra          20
# ...            ...         ...
# 46695     Zimbabwe         716
# 46696     Zimbabwe         716
# 46697     Zimbabwe         716
# 46698     Zimbabwe         716
# 46699     Zimbabwe         716
#
# [46700 rows x 6 columns]

# %%
other_ufo_df['city_name'] = other_ufo_df['city_name'].str.rstrip()
other_ufo_df.head()
# Out:
#                                                summary    state     shape  \
# 12   A series of soft white lights were traveling i...  unknown     light
# 84                       Big UFO hovering over a house  unknown     other
# 88               30+ orange balls playing in Australia  unknown  fireball
# 96   Simple triangle 40/50 yards across. Blue soft ...  unknown  triangle
# 123                                       Cube of Fire  unknown  fireball
#
#           duration        date       time       city_name  \
# 12   10-15 minutes  2020/01/10    morning         Chennai
# 84            4:00  1980/06/01  afternoon      Comalcalco
# 88       5 minutes  1982/03/16    evening          Hobart
# 96       7 minutes  1988/06/01      night        Hahn A B
# 123      4 minutes  1999/04/04    evening  Stoke on Trent
#
#                                           country_name
# 12                                               India
# 84                                              Mexico
# 88                                           Australia
# 96                                             Germany
# 123  United Kingdom of Great Britain and Northern I...

# %%
# Merge again for city data
merged_df = other_ufo_df.merge(city_data, on=['country_name',"city_name"], how="inner")
merged_df = merged_df.set_index('country_id')

# %% [markdown]
# ### Preparing to export to CSV

# %% [markdown]
# ### NOTE: Due to time constraint, there will be missing US cities in the city table

# %%
usa_ufo_df.head()
# Out:
#                                                       summary   city_name  \
# country_id
# 840.0                                          freaked me out    San Jose
# 840.0       Over a course of 5 years, I have seen UFOs, ob...  Germantown
# 840.0       Driving north on US 87 just outside Brady, Tex...       Brady
# 840.0                                   meteor or space junk?   San Diego
# 840.0       Shaped like a triangle, transparent like a lig...   Las Vegas
#
#            state      shape          duration  city_latitude  city_longitude  \
# country_id
# 840.0         CA     sphere         2 minutes      37.338842     -121.889706
# 840.0         MD  formation             Years      39.154986      -77.272538
# 840.0         TX      light  Lights disappear      31.145100      -99.347800
# 840.0         CA   fireball         2 seconds      32.787229     -117.140268
# 840.0         NV   triangle                30      36.141246     -115.186592
#
#                   date       time
# country_id
# 840.0       2021/05/06    evening
# 840.0       2005/07/06  afternoon
# 840.0       2020/01/29    evening
# 840.0       2020/01/29    evening
# 840.0       2020/01/28  afternoon

# %%
merged_df.head()
# Out:
#                                                       summary    state  \
# country_id
# 484                             Big UFO hovering over a house  unknown
# 36                      30+ orange balls playing in Australia  unknown
# 36                         Strange orange light in Australia.  unknown
# 826         rectangle shinny glass like blue box in the sk...  unknown
# 826         A Sphere in the sky that disappeared in a matt...  unknown
#
#                 shape    duration        date       time   city_name  \
# country_id
# 484             other        4:00  1980/06/01  afternoon  Comalcalco
# 36           fireball   5 minutes  1982/03/16    evening      Hobart
# 36              light    1 minute  2013/05/06      night      Hobart
# 826         rectangle      1 hour  2009/06/30    evening      Oxford
# 826            sphere  20 seconds  1986/06/15  afternoon      Oxford
#
#                                                  country_name country_abb  \
# country_id
# 484                                                    Mexico          MX
# 36                                                  Australia          AU
# 36                                                  Australia          AU
# 826         United Kingdom of Great Britain and Northern I...          GB
# 826         United Kingdom of Great Britain and Northern I...          GB
#
#             city_latitude  city_longitude
# country_id
# 484             18.266667      -93.216667
# 36             -42.883209      147.331665
# 36             -42.883209      147.331665
# 826             51.750000       -1.250000
# 826             51.750000       -1.250000

# %%
sightings_df = pd.concat([merged_df, usa_ufo_df])
sightings_df.head()
# Out:
#                                                       summary    state  \
# country_id
# 484.0                           Big UFO hovering over a house  unknown
# 36.0                    30+ orange balls playing in Australia  unknown
# 36.0                       Strange orange light in Australia.  unknown
# 826.0       rectangle shinny glass like blue box in the sk...  unknown
# 826.0       A Sphere in the sky that disappeared in a matt...  unknown
#
#                 shape    duration        date       time   city_name  \
# country_id
# 484.0           other        4:00  1980/06/01  afternoon  Comalcalco
# 36.0         fireball   5 minutes  1982/03/16    evening      Hobart
# 36.0            light    1 minute  2013/05/06      night      Hobart
# 826.0       rectangle      1 hour  2009/06/30    evening      Oxford
# 826.0          sphere  20 seconds  1986/06/15  afternoon      Oxford
#
#                                                  country_name country_abb  \
# country_id
# 484.0                                                  Mexico          MX
# 36.0                                                Australia          AU
# 36.0                                                Australia          AU
# 826.0       United Kingdom of Great Britain and Northern I...          GB
# 826.0       United Kingdom of Great Britain and Northern I...          GB
#
#             city_latitude  city_longitude
# country_id
# 484.0           18.266667      -93.216667
# 36.0           -42.883209      147.331665
# 36.0           -42.883209      147.331665
# 826.0           51.750000       -1.250000
# 826.0           51.750000       -1.250000

# %%
sightings_df.drop('country_name', axis=1, inplace=True)
sightings_df.drop('country_abb', axis=1, inplace=True)
sightings_df = sightings_df.rename(columns = {'city_name' : 'city'})
#sightings_df.sort_index()
sightings_df.head()
# Out:
#                                                       summary    state  \
# country_id
# 484.0                           Big UFO hovering over a house  unknown
# 36.0                    30+ orange balls playing in Australia  unknown
# 36.0                       Strange orange light in Australia.  unknown
# 826.0       rectangle shinny glass like blue box in the sk...  unknown
# 826.0       A Sphere in the sky that disappeared in a matt...  unknown
#
#                 shape    duration        date       time        city  \
# country_id
# 484.0           other        4:00  1980/06/01  afternoon  Comalcalco
# 36.0         fireball   5 minutes  1982/03/16    evening      Hobart
# 36.0            light    1 minute  2013/05/06      night      Hobart
# 826.0       rectangle      1 hour  2009/06/30    evening      Oxford
# 826.0          sphere  20 seconds  1986/06/15  afternoon      Oxford
#
#             city_latitude  city_longitude
# country_id
# 484.0           18.266667      -93.216667
# 36.0           -42.883209      147.331665
# 36.0           -42.883209      147.331665
# 826.0           51.750000       -1.250000
# 826.0           51.750000       -1.250000

# %%
cleaned_country_df = cleaned_country_df.set_index("country_id")
cleaned_country_df = cleaned_country_df.rename(columns = {'country_abb' : 'country_abbreviation'})

# %%
# x = cleaned_country_df[cleaned_country_df['country_id'] == " Sint Eustatius and Saba"]
# x

# %%
cleaned_country_df.head()
# Out:
#            country_name country_abbreviation
# country_id
# 12              Algeria                   DZ
# 818               Egypt                   EG
# 434               Libya                   LY
# 504             Morocco                   MA
# 729               Sudan                   SD

# %%
# Save as CSV
cleaned_country_df.to_csv("static/Resources/cleaned_country_data.CSV", index = True)
sightings_df.to_csv("static/Resources/sightings_data.CSV", index = True)
